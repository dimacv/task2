# %%
# %matplotlib inline
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import statsmodels.api as sm
import statsmodels.base.model
import statsmodels.tsa.api as smt
from statsmodels.tsa.arima_model import ARIMA
from sklearn.metrics import r2_score, roc_auc_score, roc_curve
import ml_metrics as metrics
from itertools import product
from tqdm import tqdm

# %%
def show_plot(df):
    plt.figure(figsize = (12, 7))
    layout = (2, 2)
    ts_ax = plt.subplot2grid(layout, (0, 0), colspan=2)
    acf_ax = plt.subplot2grid(layout, (1, 0))
    pacf_ax = plt.subplot2grid(layout, (1, 1))

    df.plot(ax = ts_ax)
    smt.graphics.plot_acf(df, lags = 30, ax = acf_ax, alpha = 0.5)
    smt.graphics.plot_pacf(df, lags = 30, ax = pacf_ax, alpha = 0.5)

    plt.tight_layout()
    
def decomposition(df, model):
    plt.figure(figsize = (12, 7))
    r = statsmodels.tsa.seasonal.seasonal_decompose(df['Value'], model=model) 
    plt.plot(r.seasonal, c = 'red', label = 'Seasonal component')
    plt.plot(r.trend, label = 'Trend')
    plt.plot(r.resid, c = 'grey', label = 'Lags')
    plt.legend(loc = 'upper left')

# %%
df = pd.read_csv('training.csv', ",", parse_dates=['Date'], dayfirst=True)
df['Date'] = pd.to_datetime(df['Date'])
df.tail()
# Out:
#           Date    Value
# 355 1988-08-01  63.8851
# 356 1988-09-01  63.7040
# 357 1988-10-01  64.0220
# 358 1988-11-01  64.1173
# 359 1988-12-01  64.4210

# %%
plt.figure(figsize=(12,7))
plt.plot(df['Date'], df['Value'], label = "Time Series")
##
rolling_mean = df['Value'].rolling(window=10).mean()

plt.plot(df['Date'],rolling_mean, "g", label="Rolling mean trend")
plt.legend(loc="upper left")


plt.grid(True)
plt.tight_layout()

# %%
show_plot(df['Value'])

# %% [markdown]
# ## Аддитивная модель

# %%
decomposition(df, 'additive')

# %% [markdown]
# ## Мультипликативная модель

# %%
decomposition(df, 'multiplicative')

# %% [markdown]
# Заметим, что в мультипликативной модели меньше разброс ошибок

# %%
import statsmodels.formula.api as sm

x = pd.Series(np.arange(50))
y = pd.Series(10 + (2 * x + np.random.randint(-5, + 5, 50)))
regression = sm.ols(y=y, x=x).fit()


regression.summary
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-11-5c76eae8a206> in <module>()
#       3 x = pd.Series(np.arange(50))
#       4 y = pd.Series(10 + (2 * x + np.random.randint(-5, + 5, 50)))
# ----> 5 regression = sm.ols(y=y, x=x).fit()
#       6
#       7
#
# TypeError: from_formula() missing 2 required positional arguments: 'formula' and 'data'

# %%
plt.figure(figsize = (12, 7))
rolling_std = df['Value'].rolling(window=20).std()
plt.plot(df['Date'], rolling_std, "g", label="Rolling std trend")
plt.legend(loc="upper left")
plt.grid(True)

# %%
df['Value'] = df['Value'].dropna()
test = sm.tsa.adfuller(df['Value'])
print ( 'adf: ', test[0])
print ('p-value: ', test[1])
print('Critical values: ', test[4])
if test[0]> test[4]['5%']: 
    print ('есть единичные корни, ряд не стационарен')
else:
    print ('единичных корней нет, ряд стационарен')
# Out:
# adf:  -0.253391179928
# p-value:  0.931851042299
# Critical values:  {'1%': -3.4489583388155194, '5%': -2.869739378430086, '10%': -2.5711381780459002}
# есть единичные корни, ряд не стационарен

# %%
df1 = df['Value'].diff(periods=1).dropna()
df1.head()
# Out:
# 1    0.4471
# 2    0.3354
# 3    0.5030
# 4    0.3634
# 5    0.0279
# Name: Value, dtype: float64

# %%
test = sm.tsa.adfuller(df1)
print ( 'adf: ', test[0])
print ('p-value: ', test[1])
print('Critical values: ', test[4])
if test[0]> test[4]['5%']: 
    print ('есть единичные корни, ряд не стационарен')
else:
    print ('единичных корней нет, ряд стационарен')
# Out:
# adf:  -7.36731149521
# p-value:  9.1641495611e-11
# Critical values:  {'1%': -3.4489583388155194, '5%': -2.869739378430086, '10%': -2.5711381780459002}
# единичных корней нет, ряд стационарен

# %%
# %matplotlib inline
plt.figure(figsize = (12, 7))
plt.grid(True)
df1.plot() #интегрированный ряд первого порядка

# %%
show_plot(df1) #интегрированный ряд первого порядка, его автокореляция и частичная автокорелляция

# %%
X = df.Value
train, test = X[0:-30], X[329:]
history = [x for x in train]
testing = [x for x in test]
model = smt.statespace.SARIMAX(history, order=(1,1,1)).fit()
print(model.summary())
# Out:
#                            Statespace Model Results
# ==============================================================================
# Dep. Variable:                      y   No. Observations:                  330
# Model:               SARIMAX(1, 1, 1)   Log Likelihood                -119.030
# Date:                Tue, 14 Nov 2017   AIC                            244.061
# Time:                        16:08:32   BIC                            255.458
# Sample:                             0   HQIC                           248.607
#                                 - 330
# Covariance Type:                  opg
# ==============================================================================
#                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------
# ar.L1          0.6871      0.075      9.171      0.000       0.540       0.834
# ma.L1         -0.2909      0.090     -3.233      0.001      -0.467      -0.115
# sigma2         0.1206      0.006     19.480      0.000       0.108       0.133
# ===================================================================================
# Ljung-Box (Q):                       52.41   Jarque-Bera (JB):               118.11
# Prob(Q):                              0.09   Prob(JB):                         0.00
# Heteroskedasticity (H):               1.83   Skew:                             0.15
# Prob(H) (two-sided):                  0.00   Kurtosis:                         5.92
# ===================================================================================
#
# Warnings:
# [1] Covariance matrix calculated using the outer product of gradients (complex-step).

# %%
ps = range(0, 5)
qs = range(0, 4)

parameters = product(ps, qs)
parameters_list = list(parameters)
len(parameters_list)

predictions = list()
results = []
best_aic = float("inf")

for param in tqdm(parameters_list):
    #try except нужен, потому что на некоторых наборах параметров модель не обучается
    try:
        model=sm.tsa.ARIMA(train, order=(param[0], 1, param[1]), dates = df['Date'], freq='W').fit()
    #выводим параметры, на которых модель не обучается и переходим к следующему набору
    except ValueError:
        print('wrong parameters:', param)
        continue
    aic = model.aic
    #сохраняем лучшую модель, aic, параметры
    if aic < best_aic:
        best_model = model
        best_aic = aic
        best_param = param
    results.append([param, model.aic])
# Out:
# 100%|██████████| 20/20 [00:02<00:00,  7.64it/s]

# %%
#df.index = pd.DatetimeIndex(end=pd.datetime.today(), periods=len(df), freq='1D')
model = sm.tsa.ARIMA(train, order=(2,1,2), dates = df['Date'], freq='W' ).fit()
print(model.summary())
# Out:
#                              ARIMA Model Results
# ==============================================================================
# Dep. Variable:                D.Value   No. Observations:                  329
# Model:                 ARIMA(2, 1, 2)   Log Likelihood                -115.183
# Method:                       css-mle   S.D. of innovations              0.343
# Date:                Tue, 14 Nov 2017   AIC                            242.367
# Time:                        16:02:01   BIC                            265.143
# Sample:                    02-01-1959   HQIC                           251.453
#                          - 12-01-1988
# =================================================================================
#                     coef    std err          z      P>|z|      [0.025      0.975]
# ---------------------------------------------------------------------------------
# const             0.1043      0.039      2.701      0.007       0.029       0.180
# ar.L1.D.Value     0.4176      0.503      0.830      0.407      -0.569       1.404
# ar.L2.D.Value     0.1728      0.298      0.580      0.562      -0.411       0.757
# ma.L1.D.Value    -0.0235      0.501     -0.047      0.963      -1.005       0.958
# ma.L2.D.Value    -0.1372      0.132     -1.040      0.299      -0.396       0.121
#                                     Roots
# =============================================================================
#                  Real           Imaginary           Modulus         Frequency
# -----------------------------------------------------------------------------
# AR.1            1.4836           +0.0000j            1.4836            0.0000
# AR.2           -3.8998           +0.0000j            3.8998            0.5000
# MA.1            2.6150           +0.0000j            2.6150            0.0000
# MA.2           -2.7863           +0.0000j            2.7863            0.5000
# -----------------------------------------------------------------------------

# %%
a = statsmodels.tsa.seasonal.seasonal_decompose(df['Value'], freq = None)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-229-f9fbb40f0860> in <module>()
# ----> 1 a = statsmodels.tsa.seasonal.seasonal_decompose(df['Value'], freq = None)
#
# /anaconda/lib/python3.6/site-packages/statsmodels/tsa/seasonal.py in seasonal_decompose(x, model, filt, freq, two_sided)
#      66     statsmodels.tsa.filters.convolution_filter
#      67     """
# ---> 68     _pandas_wrapper, pfreq = _maybe_get_pandas_wrapper_freq(x)
#      69     x = np.asanyarray(x).squeeze()
#      70     nobs = len(x)
#
# /anaconda/lib/python3.6/site-packages/statsmodels/tsa/filters/_utils.py in _maybe_get_pandas_wrapper_freq(X, trim)
#      44         index = X.index
#      45         func = _get_pandas_wrapper(X, trim)
# ---> 46         freq = index.inferred_freq
#      47         return func, freq
#      48     else:
#
# AttributeError: 'RangeIndex' object has no attribute 'inferred_freq'

# %%
model1 = sm.tsa.SARIMAX(train, order=(2,1,2), trend = , dates = df['Date'], freq='W' ).fit()
print(model.summary())
pred = model.predict(start = '1986-06-01', end='1988-12-01')
r2 = r2_score(test, pred[1:32])
print ('R^2: %1.2f' % r2)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-208-6d91729ac813> in <module>()
# ----> 1 model1 = sm.tsa.SARIMAX(train, order=(2,1,2), trend = statsmodels.tsa.seasonal.seasonal_decompose(df['Value']).trend, dates = df['Date'], freq='W' ).fit()
#       2 print(model.summary())
#       3 pred = model.predict(start = '1986-06-01', end='1988-12-01')
#       4 r2 = r2_score(test, pred[1:32])
#       5 print ('R^2: %1.2f' % r2)
#
# /anaconda/lib/python3.6/site-packages/statsmodels/tsa/seasonal.py in seasonal_decompose(x, model, filt, freq, two_sided)
#      66     statsmodels.tsa.filters.convolution_filter
#      67     """
# ---> 68     _pandas_wrapper, pfreq = _maybe_get_pandas_wrapper_freq(x)
#      69     x = np.asanyarray(x).squeeze()
#      70     nobs = len(x)
#
# /anaconda/lib/python3.6/site-packages/statsmodels/tsa/filters/_utils.py in _maybe_get_pandas_wrapper_freq(X, trim)
#      44         index = X.index
#      45         func = _get_pandas_wrapper(X, trim)
# ---> 46         freq = index.inferred_freq
#      47         return func, freq
#      48     else:
#
# AttributeError: 'RangeIndex' object has no attribute 'inferred_freq'

# %%
pred = model.predict(start = '1986-06-01', end='1988-12-01')
r2 = r2_score(test, pred[1:32])
print ('R^2: %1.2f' % r2)
# Out:
# R^2: -592.44

# %%
metrics.rmse(test,pred[1:32])
# Out:
# 60.985180890414554

# %%
pred.plot(style='r--')

# %%
plt.figure(figsize = (12, 7))
rolling_mean1 = df1.rolling(window=10).mean()
plt.plot(rolling_mean1, "g", label="Rolling mean trend")
