# %%
# %matplotlib inline
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import statsmodels.api as sm
import statsmodels.tsa.api as smt
from statsmodels.tsa.arima_model import ARIMA

# %%
def show_plot(df):
    plt.figure(figsize = (12, 7))
    layout = (2, 2)
    ts_ax = plt.subplot2grid(layout, (0, 0), colspan=2)
    acf_ax = plt.subplot2grid(layout, (1, 0))
    pacf_ax = plt.subplot2grid(layout, (1, 1))

    df.plot(ax = ts_ax)
    smt.graphics.plot_acf(df, lags = 30, ax = acf_ax, alpha = 0.5)
    smt.graphics.plot_pacf(df, lags = 30, ax = pacf_ax, alpha = 0.5)

    plt.tight_layout()
    
def decomposition(df, model):
    r = statsmodels.tsa.seasonal.seasonal_decompose(df.Value, model = model) 
    plt.figure(figsize = (12, 7))
    plt.plot(r.seasonal, c = 'red', label = 'Seasonal component')
    plt.plot(r.trend, label = 'Trend')
    plt.plot(r.resid, c = 'grey', label = 'Lags')
    plt.legend(loc = 'upper left')

# %%
df = pd.read_csv('training.csv', ",", parse_dates=['Date'], dayfirst=True)
df['Date'] = pd.to_datetime(df['Date'])
df.head()
# Out:
#         Date    Value
# 0 1959-01-01  22.8331
# 1 1959-02-01  23.2802
# 2 1959-03-01  23.6156
# 3 1959-04-01  24.1186
# 4 1959-05-01  24.4820

# %%
plt.figure(figsize=(12,7))
plt.plot(df['Date'], df['Value'], label = "Time Series")
##
rolling_mean = df['Value'].rolling(window=10).mean()

plt.plot(df['Date'],rolling_mean, "g", label="Rolling mean trend")
plt.legend(loc="upper left")


plt.grid(True)
plt.tight_layout()

# %%
show_plot(df['Value'])

# %% [markdown]
# ## Аддитивная модель

# %%
decomposition(df, 'additive')

# %% [markdown]
# ## Мультипликативная модель

# %%
decomposition(df, 'multiplicative')

# %% [markdown]
# Заметим, что в мультипликативной модели меньше разброс ошибок

# %%
import statsmodels.formula.api as sm

x = pd.Series(np.arange(50))
y = pd.Series(10 + (2 * x + np.random.randint(-5, + 5, 50)))
regression = sm.ols(y=y, x=x).fit()


regression.summary
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-216-5c76eae8a206> in <module>()
#       3 x = pd.Series(np.arange(50))
#       4 y = pd.Series(10 + (2 * x + np.random.randint(-5, + 5, 50)))
# ----> 5 regression = sm.ols(y=y, x=x).fit()
#       6
#       7
#
# TypeError: from_formula() missing 2 required positional arguments: 'formula' and 'data'

# %%
plt.figure(figsize = (12, 7))
rolling_std = df['Value'].rolling(window=20).std()
plt.plot(df['Date'], rolling_std, "g", label="Rolling std trend")
plt.legend(loc="upper left")
plt.grid(True)

# %%
df['Value'] = df['Value'].dropna()
test = sm.tsa.adfuller(df['Value'])
print ( 'adf: ', test[0])
print ('p-value: ', test[1])
print('Critical values: ', test[4])
if test[0]> test[4]['5%']: 
    print ('есть единичные корни, ряд не стационарен')
else:
    print ('единичных корней нет, ряд стационарен')
# Out:
# adf:  -0.253391179928
# p-value:  0.931851042299
# Critical values:  {'1%': -3.4489583388155194, '5%': -2.869739378430086, '10%': -2.5711381780459002}
# есть единичные корни, ряд не стационарен

# %%
df1 = df['Value'].diff(periods=1).dropna()
df1.head()
# Out:
# 1    0.4471
# 2    0.3354
# 3    0.5030
# 4    0.3634
# 5    0.0279
# Name: Value, dtype: float64

# %%
test = sm.tsa.adfuller(df1)
print ( 'adf: ', test[0])
print ('p-value: ', test[1])
print('Critical values: ', test[4])
if test[0]> test[4]['5%']: 
    print ('есть единичные корни, ряд не стационарен')
else:
    print ('единичных корней нет, ряд стационарен')
# Out:
# adf:  -7.36731149521
# p-value:  9.1641495611e-11
# Critical values:  {'1%': -3.4489583388155194, '5%': -2.869739378430086, '10%': -2.5711381780459002}
# единичных корней нет, ряд стационарен

# %%
# %matplotlib inline
plt.figure(figsize = (12, 7))
plt.grid(True)
df1.plot() #интегрированный ряд первого порядка

# %%
show_plot(df1) #интегрированный ряд первого порядка, его автокореляция и частичная автокорелляция

# %%
X = df.Value
train, test = X[0:-30], X[330:]
history = [x for x in train]
model = sm.tsa.statespace.SARIMAX(history, order=(1,1,1)).fit(disp=-1)
print(model.summary())
# Out:
#                            Statespace Model Results
# ==============================================================================
# Dep. Variable:                      y   No. Observations:                  330
# Model:               SARIMAX(1, 1, 1)   Log Likelihood                -119.030
# Date:                Fri, 03 Nov 2017   AIC                            244.061
# Time:                        13:25:25   BIC                            255.458
# Sample:                             0   HQIC                           248.607
#                                 - 330
# Covariance Type:                  opg
# ==============================================================================
#                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------
# ar.L1          0.6871      0.075      9.171      0.000       0.540       0.834
# ma.L1         -0.2909      0.090     -3.233      0.001      -0.467      -0.115
# sigma2         0.1206      0.006     19.480      0.000       0.108       0.133
# ===================================================================================
# Ljung-Box (Q):                       52.41   Jarque-Bera (JB):               118.11
# Prob(Q):                              0.09   Prob(JB):                         0.00
# Heteroskedasticity (H):               1.83   Skew:                             0.15
# Prob(H) (two-sided):                  0.00   Kurtosis:                         5.92
# ===================================================================================
#
# Warnings:
# [1] Covariance matrix calculated using the outer product of gradients (complex-step).

# %%
predictions = list()
for t in range(len(test)):
    # fit model
    model = ARIMA(history, order=(1,1,1))
    model_fit = model.fit(disp=-1)
    # one step forecast
    yhat = model_fit.forecast()[0]
    # store forecast and ob
    predictions.append(yhat)
    history.append(test[t])
    print((yhat, test[t]))
plt.plot(test)
plt.plot(predictions, color='red')
plt.show()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-126-799fa6259b0a> in <module>()
#       2 for t in range(len(test)):
#       3     # fit model
# ----> 4     model = smt.ARMA(history, order=(1,1,1), transparams=False)
#       5     model_fit = model.fit(disp=-1)
#       6     # one step forecast
#
# TypeError: __init__() got an unexpected keyword argument 'transparams'

# %%
show_plot(model.resid[24:])
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-117-dfc6a7b45e23> in <module>()
# ----> 1 show_plot(model.resid[24:])
#
# <ipython-input-95-0d205361432e> in show_plot(df)
#       6     pacf_ax = plt.subplot2grid(layout, (1, 1))
#       7
# ----> 8     df.plot(ax = ts_ax)
#       9     smt.graphics.plot_acf(df, lags = 30, ax = acf_ax, alpha = 0.5)
#      10     smt.graphics.plot_pacf(df, lags = 30, ax = pacf_ax, alpha = 0.5)
#
# AttributeError: 'numpy.ndarray' object has no attribute 'plot'

# %%
#df.index = pd.DatetimeIndex(end=pd.datetime.today(), periods=len(df), freq='1D')
model = ARIMA(df, order = (1, 1, 1))
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-98-a83a2bd2bc06> in <module>()
#       1 #df.index = pd.DatetimeIndex(end=pd.datetime.today(), periods=len(df), freq='1D')
# ----> 2 model = ARIMA(df, order = (1, 1, 1))
#
# /anaconda/lib/python3.6/site-packages/statsmodels/tsa/arima_model.py in __new__(cls, endog, order, exog, dates, freq, missing)
#     998         else:
#     999             mod = super(ARIMA, cls).__new__(cls)
# -> 1000             mod.__init__(endog, order, exog, dates, freq, missing)
#    1001             return mod
#    1002
#
# /anaconda/lib/python3.6/site-packages/statsmodels/tsa/arima_model.py in __init__(self, endog, order, exog, dates, freq, missing)
#    1013             # in the predict method
#    1014             raise ValueError("d > 2 is not supported")
# -> 1015         super(ARIMA, self).__init__(endog, (p, q), exog, dates, freq, missing)
#    1016         self.k_diff = d
#    1017         self._first_unintegrate = unintegrate_levels(self.endog[:d], d)
#
# /anaconda/lib/python3.6/site-packages/statsmodels/tsa/arima_model.py in __init__(self, endog, order, exog, dates, freq, missing)
#     450     def __init__(self, endog, order, exog=None, dates=None, freq=None,
#     451                  missing='none'):
# --> 452         super(ARMA, self).__init__(endog, exog, dates, freq, missing=missing)
#     453         exog = self.data.exog  # get it after it's gone through processing
#     454         _check_estimable(len(self.endog), sum(order))
#
# /anaconda/lib/python3.6/site-packages/statsmodels/tsa/base/tsa_model.py in __init__(self, endog, exog, dates, freq, missing)
#      41
#      42     def __init__(self, endog, exog=None, dates=None, freq=None, missing='none'):
# ---> 43         super(TimeSeriesModel, self).__init__(endog, exog, missing=missing)
#      44         self._init_dates(dates, freq)
#      45
#
# /anaconda/lib/python3.6/site-packages/statsmodels/base/model.py in __init__(self, endog, exog, **kwargs)
#     210
#     211     def __init__(self, endog, exog=None, **kwargs):
# --> 212         super(LikelihoodModel, self).__init__(endog, exog, **kwargs)
#     213         self.initialize()
#     214
#
# /anaconda/lib/python3.6/site-packages/statsmodels/base/model.py in __init__(self, endog, exog, **kwargs)
#      61         hasconst = kwargs.pop('hasconst', None)
#      62         self.data = self._handle_data(endog, exog, missing, hasconst,
# ---> 63                                       **kwargs)
#      64         self.k_constant = self.data.k_constant
#      65         self.exog = self.data.exog
#
# /anaconda/lib/python3.6/site-packages/statsmodels/base/model.py in _handle_data(self, endog, exog, missing, hasconst, **kwargs)
#      86
#      87     def _handle_data(self, endog, exog, missing, hasconst, **kwargs):
# ---> 88         data = handle_data(endog, exog, missing, hasconst, **kwargs)
#      89         # kwargs arrays could have changed, easier to just attach here
#      90         for key in kwargs:
#
# /anaconda/lib/python3.6/site-packages/statsmodels/base/data.py in handle_data(endog, exog, missing, hasconst, **kwargs)
#     628     klass = handle_data_class_factory(endog, exog)
#     629     return klass(endog, exog=exog, missing=missing, hasconst=hasconst,
# --> 630                  **kwargs)
#
# /anaconda/lib/python3.6/site-packages/statsmodels/base/data.py in __init__(self, endog, exog, missing, hasconst, **kwargs)
#      74             self.orig_endog = endog
#      75             self.orig_exog = exog
# ---> 76             self.endog, self.exog = self._convert_endog_exog(endog, exog)
#      77
#      78         # this has side-effects, attaches k_constant and const_idx
#
# /anaconda/lib/python3.6/site-packages/statsmodels/base/data.py in _convert_endog_exog(self, endog, exog)
#     469         exog = exog if exog is None else np.asarray(exog)
#     470         if endog.dtype == object or exog is not None and exog.dtype == object:
# --> 471             raise ValueError("Pandas data cast to numpy dtype of object. "
#     472                              "Check input data with np.asarray(data).")
#     473         return super(PandasData, self)._convert_endog_exog(endog, exog)
#
# ValueError: Pandas data cast to numpy dtype of object. Check input data with np.asarray(data).

# %%
plt.figure(figsize = (12, 7))
rolling_mean1 = df1.rolling(window=10).mean()
plt.plot(rolling_mean1, "g", label="Rolling mean trend")

# %%
itog = df.describe()
df.hist()
itog
# Out:
#             Value
# count  360.000000
# mean    43.347284
# std     11.445942
# min     22.833100
# 25%     35.843875
# 50%     44.769500
# 75%     52.962875
# max     64.421000
